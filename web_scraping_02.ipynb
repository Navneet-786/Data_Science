# %% [markdown]
# ### we going to scrap a gaming website

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
total_pages = 90
pg_lst = list(range(1, total_pages+1))

headers = {
    "User-Agent":"Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Mobile Safari/537.36"
}
all_games = []
for page in pg_lst:
    url = f"https://sandbox.oxylabs.io/products?page={page}"
    res = requests.get(url, headers=headers)

    soup = BeautifulSoup(res.text, "lxml")

    products = soup.find_all("div",class_="product-card")
    for product in products:
        #game name
       game_name = product.find("a").find("h4" ,class_="title").get_text().strip()

        #game desc
       description = product.find("p", class_="description").get_text().strip()[:400]

        #game price
       price = product.find("p", class_="description").find_next("div").get_text().replace("€", "")

        #game status
       status_tag = product.select_one("p[class*='stock']")
       status = status_tag.get_text(strip=True) if status_tag else "In Stock"

        #game categories
       tags = product.find("p", class_="category").find_all("span")
       categories = [x.get_text().strip() for x in tags ]
        
       all_games.append([game_name, description, price, categories,status])

# %%
df = pd.DataFrame(all_games, columns=['Game','Desc',"Price","Categories","Status"])
df
# Out:
#                                        Game  \
# 0      The Legend of Zelda: Ocarina of Time
# 1                        Super Mario Galaxy
# 2                      Super Mario Galaxy 2
# 3                             Metroid Prime
# 4                       Super Mario Odyssey
# ..                                      ...
# 251       Ghost of Tsushima: Director's Cut
# 252  Grand Theft Auto: Liberty City Stories
# 253                  Medieval II: Total War
# 254                     Super Mario Maker 2
# 255                  Sly 2: Band of Thieves
#
#                                                   Desc   Price  \
# 0    As a young boy, Link is tricked by Ganondorf, ...  91,99
# 1    [Metacritic's 2007 Wii Game of the Year] The u...  91,99
# 2    Super Mario Galaxy 2, the sequel to the galaxy...  91,99
# 3    Samus returns in a new mission to unravel the ...  89,99
# 4    New Evolution of Mario Sandbox-Style Gameplay....  89,99
# ..                                                 ...     ...
# 251  Ghost of Tsushima Director's Cut includes: Gho...  67,99
# 252  Grand Theft Auto: Liberty City Stories is an e...  77,99
# 253  Medieval 2: Total War boasts an impressive arr...  90,99
# 254  Mario fans of the world, unite! Now you can pl...  85,99
# 255  Incorporating a creative new approach to team ...  90,99
#
#                                    Categories    Status
# 0                 [Action Adventure, Fantasy]  In Stock
# 1                    [Action, Platformer, 3D]  In Stock
# 2                    [Action, Platformer, 3D]  In Stock
# 3     [Action, Shooter, First-Person, Sci-Fi]  In Stock
# 4                    [Action, Platformer, 3D]  In Stock
# ..                                        ...       ...
# 251            [Action Adventure, Open-World]  In Stock
# 252    [Action Adventure, Modern, Open-World]  In Stock
# 253  [Strategy, Real-Time, Historic, General]  In Stock
# 254                  [Action, Platformer, 2D]  In Stock
# 255                  [Action, Platformer, 3D]  In Stock
#
# [256 rows x 5 columns]
